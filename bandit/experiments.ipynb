# %%
import numpy as np
import matplotlib.pyplot as plt
from epsilon_greedy import Actions, run_experiment

# %% [markdown]
# ## Experimento 1

# %%
c_1 = run_experiment(1.0, 2.0, 3.0, 0.1, 100000)
# Out:
# 0.9998073444095821
# 2.0304611328796827
# 3.0022336979766693

# %% [markdown]
# ## Experimento 2

# %%
c_05 = run_experiment(1.0, 2.0, 3.0, 0.05, 100000)
# Out:
# 0.9936891455494318
# 2.0034345000457012
# 3.0019568988579595

# %% [markdown]
# ## Experimento 3

# %%
c_01 = run_experiment(1.0, 2.0, 3.0, 0.01, 100000)
# Out:
# 1.0029416818270103
# 1.951363706309559
# 3.000300690176989

# %% [markdown]
# ## Análise geral

# %% [markdown]
# ### Log plot

# %%
plt.plot(c_1, label ='eps = 0.1') 
plt.plot(c_05, label ='eps = 0.05') 
plt.plot(c_01, label ='eps = 0.01') 
plt.legend() 
plt.xscale('log') 
plt.show()

# %% [markdown]
# ### Linear plot

# %%
plt.figure(figsize=(12, 8))
plt.plot(c_1, label='eps = 0.1')
plt.plot(c_05, label='eps = 0.05')
plt.plot(c_01, label='eps = 0.01')
plt.legend()
plt.show()
